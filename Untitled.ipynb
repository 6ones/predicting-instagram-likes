# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('./instablog9ja.csv')
print(df.shape)
df.head()
# Out:
# (5467, 13)
#    HoursPosted  timePosted 24hr     mediatype  likes   isAd  comments  views  \
# 0            1               10    GraphImage    675   True        27      0
# 1            1               10    GraphVideo   6371  False       977  56675
# 2            1               10  GraphSidecar   5407  False       454      0
# 3            2                9  GraphSidecar   1495   True         0      0
# 4            3                8    GraphImage   5727  False       627      0
#
#    ratioLikesToHoursPosted  ratioVideoViewToHoursPosted  \
# 0                    675.0                          0.0
# 1                   6371.0                      56675.0
# 2                   5407.0                          0.0
# 3                    747.5                          0.0
# 4                   1909.0                          0.0
#
#    ratioCommentsToHoursPosted  noOfHashtags  noOfMentions  noOfFollowers
# 0                        27.0             0             2        2468685
# ...

# %%
colors = {'likes':'r', 'comments':'b'}


# for i in range(len(df['likes'])):
#     sns.regplot(data=df, x=df['comments'][i], y=df['likes'][i])

sns.regplot(data=df, x="comments", y="likes", fit_reg=True, x_jitter=0.2);
plt.xlabel('No Of Comments');
plt.ylabel('No of Likes');

# %%
df.head()
# Out:
#    HoursPosted  timePosted 24hr     mediatype  likes   isAd  comments  views  \
# 0            1               10    GraphImage    675   True        27      0
# 1            1               10    GraphVideo   6371  False       977  56675
# 2            1               10  GraphSidecar   5407  False       454      0
# 3            2                9  GraphSidecar   1495   True         0      0
# 4            3                8    GraphImage   5727  False       627      0
#
#    ratioLikesToHoursPosted  ratioVideoViewToHoursPosted  \
# 0                    675.0                          0.0
# 1                   6371.0                      56675.0
# 2                   5407.0                          0.0
# 3                    747.5                          0.0
# 4                   1909.0                          0.0
#
#    ratioCommentsToHoursPosted  noOfHashtags  noOfMentions  noOfFollowers
# 0                        27.0             0             2        2468685
# ...

# %%
sns.violinplot(data=df, y='likes', x="mediatype");

# %%
sns.violinplot(data=df, y='likes', x="timePosted 24hr")
plt.xticks(rotation=90
          );

# %%
sns.countplot(data=df, x='mediatype', hue='isAd');

# %%
base_colors = sns.color_palette()[0]
sns.countplot(df['mediatype'], color=base_colors);

# %%
# sns.violinplot(data=df, x='isAd', y="likes")
plt.hist(data=df, x='likes');
plt.xlabel('Likes');
plt.ylabel('Frequency');

# %%
sns.pairplot(df);
# Out:
# /home/bones/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:778: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   a, weights = _ravel_and_check_weights(a, weights)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0ca9582c3618> in <module>()
# ----> 1 sns.pairplot(df);
#
# ...
